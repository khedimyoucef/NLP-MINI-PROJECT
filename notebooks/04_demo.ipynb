# %% [markdown]
# # 04_demo - API and frontend demo
#
# Use this notebook to start the API and test a generation request.

# %%
# !pip -q install -r ../requirements.txt

# %% [markdown]
# ## Run API
#
# Start the FastAPI app in a terminal:
#
# ```bash
# uvicorn api.app:app --host 0.0.0.0 --port 8000
# ```

# %%
import requests
resp = requests.post('http://127.0.0.1:8000/generate', json={'theme':'a dragon afraid of fire', 'age_group':'Age5-6'})
print(resp.json())
