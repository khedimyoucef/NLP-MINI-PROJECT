# %% [markdown]
# # Fine-Tune Gemma 4 E2B-IT (QLoRA) — Safe Version
# Small model (~2.3B effective params). Fits easily on a single T4.
# Final GGUF: ~1.5 GB.

# %%
# !pip uninstall -y torchao torchvision

# %%
# !pip install -q -U git+https://github.com/huggingface/transformers.git peft bitsandbytes accelerate datasets huggingface_hub
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 12.5 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 32.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.0/529.0 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.6/660.6 kB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 105.2 MB/s eta 0:00:0000:01
#   Building wheel for transformers (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.25 requires torchvision, which is not installed.

# %%
import os, sys, torch, gc
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
BASE_DIR = '/kaggle/working'
MODEL_OUT = os.path.join(BASE_DIR, 'gemma_lora_output')
MERGED_DIR = os.path.join(BASE_DIR, 'gemma_merged_fp16')
os.makedirs(MODEL_OUT, exist_ok=True); os.makedirs(MERGED_DIR, exist_ok=True)
model_id = 'google/gemma-4-E2B-it'
print(f'GPUs: {torch.cuda.device_count()}')
# Out:
# GPUs: 2

# %%
from huggingface_hub import login
os.environ['WANDB_DISABLED'] = 'true'
try:
    from kaggle_secrets import UserSecretsClient
    login(token=UserSecretsClient().get_secret('HF_TOKEN'))
    print('Logged in via Kaggle Secrets')
except Exception:
    if 'HF_TOKEN' in os.environ: login(token=os.environ['HF_TOKEN'])
    else: print('WARNING: No HF_TOKEN found!')

# %%
from datasets import load_dataset
ds = load_dataset('ajibawa-2023/Children-Stories-Collection', split='train', cache_dir=os.path.join(BASE_DIR, 'hf_cache'))
sample_size = 10000
ds_sample = ds.shuffle(seed=42).select(range(min(sample_size, len(ds))))
PREFIXES = [
    'Level: Age3-4 — Simple words.', 'Level: Age5-6 — Short sentences.',
    'Level: Age7-8 — Moderate vocabulary.', 'Level: Age9-10 — Longer sentences.',
    'Level: Age11-12 — Richer vocabulary.'
]
def format_gemma(ex, idx):
    pfx = PREFIXES[idx % len(PREFIXES)]
    return {'text': f'<start_of_turn>user\n{pfx}\n{ex.get("prompt","")}<end_of_turn>\n<start_of_turn>model\n{ex.get("text","")}<end_of_turn>\n'}
ds_fmt = ds_sample.map(format_gemma, with_indices=True, remove_columns=ds_sample.column_names)
print(f'Formatted {len(ds_fmt)} samples')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
bnb = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_use_double_quant=True, bnb_4bit_quant_type='nf4', bnb_4bit_compute_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=bnb, device_map='auto')
print('Model loaded successfully!')

# %%
from peft import LoraConfig, get_peft_model
model.gradient_checkpointing_enable()
model.enable_input_require_grads()
for n, p in model.named_parameters():
    p.requires_grad = False
    if p.ndim == 1 and 'norm' in n.lower(): p.data = p.data.to(torch.float32)
try:
    from transformers.models.gemma4.modeling_gemma4 import Gemma4ClippableLinear
    ct = 0
    for n, m in list(model.named_modules()):
        if isinstance(m, Gemma4ClippableLinear):
            parts = n.split('.')
            setattr(model.get_submodule('.'.join(parts[:-1])), parts[-1], m.linear)
            ct += 1
    print(f'Unwrapped {ct} ClippableLinear modules')
except (ImportError, AttributeError) as e:
    print(f'Unwrap skipped: {e}')
lora_config = LoraConfig(r=16, lora_alpha=32,
    target_modules=['q_proj','k_proj','v_proj','o_proj','gate_proj','up_proj','down_proj'],
    lora_dropout=0.05, bias='none', task_type='CAUSAL_LM')
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# %%
MAX_SEQ_LEN = 256
def tok_fn(ex):
    o = tokenizer(ex['text'], truncation=True, max_length=MAX_SEQ_LEN, padding='max_length')
    o['labels'] = o['input_ids'].copy()
    return o
ds_tok = ds_fmt.map(tok_fn, batched=True, remove_columns=['text'])
sp = ds_tok.train_test_split(test_size=0.05, seed=42)
train_ds, eval_ds = sp['train'], sp['test']
print(f'Train: {len(train_ds)}, Eval: {len(eval_ds)}')

# %%
from transformers import Trainer, TrainingArguments, DataCollatorForLanguageModeling
args = TrainingArguments(output_dir=MODEL_OUT, per_device_train_batch_size=1, gradient_accumulation_steps=16,
    optim='paged_adamw_8bit', save_steps=200, save_total_limit=2, logging_steps=20,
    learning_rate=2e-4, max_grad_norm=0.3, num_train_epochs=1, warmup_steps=10,
    lr_scheduler_type='cosine', fp16=True, gradient_checkpointing=True,
    eval_strategy='no')  # Eval disabled — 256k vocab logits cause OOM during eval
trainer = Trainer(model=model, args=args, train_dataset=train_ds,
    data_collator=DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False))
print('Training with batch_size=1, grad_accum=16, gradient_checkpointing=True')
# Resume from checkpoint if one exists (e.g. after a crash)
import glob
ckpts = sorted(glob.glob(os.path.join(MODEL_OUT, 'checkpoint-*')))
resume = ckpts[-1] if ckpts else None
if resume: print(f'Resuming from {resume}')
trainer.train(resume_from_checkpoint=resume)
trainer.model.save_pretrained(MODEL_OUT); tokenizer.save_pretrained(MODEL_OUT)

# %%
print('Freeing GPU memory...')
del model, trainer
torch.cuda.empty_cache()
gc.collect()

# %%
from transformers import AutoModelForCausalLM
from peft import PeftModel
print('Loading base model in fp16 on CPU for merge...')
base = AutoModelForCausalLM.from_pretrained(model_id, dtype=torch.float16, device_map='cpu')
try:
    from transformers.models.gemma4.modeling_gemma4 import Gemma4ClippableLinear
    for n, m in list(base.named_modules()):
        if isinstance(m, Gemma4ClippableLinear):
            parts = n.split('.')
            setattr(base.get_submodule('.'.join(parts[:-1])), parts[-1], m.linear)
except Exception as e: print(e)
merged = PeftModel.from_pretrained(base, MODEL_OUT).merge_and_unload()
merged.save_pretrained(MERGED_DIR)
tokenizer.save_pretrained(MERGED_DIR)
print(f'Merged model saved to {MERGED_DIR}')
del base, merged; gc.collect()
print('Aggressively cleaning disk space...')
os.system('rm -rf ~/.cache/huggingface/hub')
os.system(f'rm -rf {MODEL_OUT}')

# %%
# %%bash
# git clone https://github.com/ggerganov/llama.cpp.git
# cd llama.cpp && cmake -B build && cmake --build build --config Release -j 4

# %%
# %%bash
# pip install ./llama.cpp/gguf-py
# python llama.cpp/convert_hf_to_gguf.py /kaggle/working/gemma_merged_fp16 --outfile /kaggle/working/ft-gemma-e2b-fp16.gguf --outtype f16
# rm -rf /kaggle/working/gemma_merged_fp16
# ./llama.cpp/build/bin/llama-quantize /kaggle/working/ft-gemma-e2b-fp16.gguf /kaggle/working/ft-gemma-e2b-Q4_K_M.gguf Q4_K_M
# rm -f /kaggle/working/ft-gemma-e2b-fp16.gguf
# ls -lh /kaggle/working/ft-gemma-e2b-Q4_K_M.gguf

# %%
from huggingface_hub import HfApi, login
from kaggle_secrets import UserSecretsClient
try:
    user_secrets = UserSecretsClient()
    login(token=user_secrets.get_secret('HF_TOKEN'))
except Exception as e:
    print('Warning: HF_TOKEN not found in secrets. If upload fails, login manually.', e)
api = HfApi()
GGUF = '/kaggle/working/ft-gemma-e2b-Q4_K_M.gguf'
api.upload_file(path_or_fileobj=GGUF, path_in_repo='finetuned-gemma-4-e2b-it-Q4_K_M.gguf', repo_id='khedim/NLP-MINI-PROJECT',
    commit_message='Upload fine-tuned Gemma 4 E2B Q4_K_M GGUF')
print('Upload Complete!')

# %%
import os
import gc
import torch
from huggingface_hub import login, HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
from kaggle_secrets import UserSecretsClient

# ==========================================
# 1. SETUP & AUTHENTICATION
# ==========================================
try:
    user_secrets = UserSecretsClient()
    login(token=user_secrets.get_secret("HF_TOKEN"))
except Exception as e:
    print("Warning: HF_TOKEN not found in secrets. If upload fails, login manually.", e)

BASE_DIR = '/kaggle/working'
MODEL_OUT = os.path.join(BASE_DIR, 'gemma_lora_output')
MERGED_DIR = os.path.join(BASE_DIR, 'gemma_merged_fp16')
model_id = 'google/gemma-4-E2B-it' # Base model ID

# Check if we survived!
if not os.path.exists(MODEL_OUT):
    print("❌ FATAL: The training output folder 'gemma_lora_output' is completely gone. You will need to restart the notebook from scratch.")
    exit(1)

# ==========================================
# 2. MERGE LORA ADAPTER INTO BASE MODEL
# ==========================================
print('\n--- MERGING LORA WEIGHTS ---')
tokenizer = AutoTokenizer.from_pretrained(model_id)
base = AutoModelForCausalLM.from_pretrained(model_id, dtype=torch.float16, device_map='cpu')

try:
    from transformers.models.gemma4.modeling_gemma4 import Gemma4ClippableLinear
    for n, m in list(base.named_modules()):
        if isinstance(m, Gemma4ClippableLinear):
            parts = n.split('.')
            setattr(base.get_submodule('.'.join(parts[:-1])), parts[-1], m.linear)
except Exception as e:
    print("Unwrapping error (can be ignored if already unwrapped):", e)

merged = PeftModel.from_pretrained(base, MODEL_OUT).merge_and_unload()
merged.save_pretrained(MERGED_DIR)
tokenizer.save_pretrained(MERGED_DIR)
print(f'Merged model successfully saved to {MERGED_DIR}')

del base, merged
gc.collect()

# ==========================================
# 3. AGGRESSIVELY CLEAR DISK SPACE
# ==========================================
print('\n--- CLEANING DISK FOR CONVERSION ---')
# The merge was successful, we no longer need the raw checkpoints or the base model cache!
os.system('rm -rf ~/.cache/huggingface/hub')
os.system(f'rm -rf {MODEL_OUT}')
os.system(f'rm -f {BASE_DIR}/ft-gemma-e2b-fp16.gguf') # delete any failed gguf attempt
os.system('df -h /kaggle/working')

# ==========================================
# 4. CONVERT TO GGUF & QUANTIZE
# ==========================================
print('\n--- CONVERTING TO GGUF AND QUANTIZING ---')
os.system('pip install ./llama.cpp/gguf-py')

# Convert FP16
print("Converting HF to GGUF (FP16)...")
os.system(f'python llama.cpp/convert_hf_to_gguf.py {MERGED_DIR} --outfile {BASE_DIR}/ft-gemma-e2b-fp16.gguf --outtype f16')

# Delete merged safetensors immediately!
os.system(f'rm -rf {MERGED_DIR}')

# Quantize to Q4_K_M
print("Quantizing to Q4_K_M...")
os.system(f'./llama.cpp/build/bin/llama-quantize {BASE_DIR}/ft-gemma-e2b-fp16.gguf {BASE_DIR}/ft-gemma-e2b-Q4_K_M.gguf Q4_K_M')

# Delete FP16 GGUF
os.system(f'rm -f {BASE_DIR}/ft-gemma-e2b-fp16.gguf')

print('\n--- FINAL FILE ---')
os.system(f'ls -lh {BASE_DIR}/ft-gemma-e2b-Q4_K_M.gguf')

# ==========================================
# 5. UPLOAD TO HUGGING FACE
# ==========================================
print('\n--- UPLOADING TO HUGGING FACE ---')
api = HfApi()
gguf_path = os.path.join(BASE_DIR, 'ft-gemma-e2b-Q4_K_M.gguf')

try:
    api.upload_file(
        path_or_fileobj=gguf_path, 
        path_in_repo='finetuned-gemma-4-e2b-it-Q4_K_M.gguf', 
        repo_id='khedim/NLP-MINI-PROJECT',
        commit_message='Upload fine-tuned Gemma 4 E2B Q4_K_M GGUF'
    )
    print('\n🎉 UPLOAD COMPLETE! THE MIRACLE HAPPENED! 🎉')
except Exception as e:
    print("\n❌ Upload failed:", e)
# Out:
# --- MERGING LORA WEIGHTS ---
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/10.2G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/1951 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/208 [00:00<?, ?B/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Merged model successfully saved to /kaggle/working/gemma_merged_fp16
#
# --- CLEANING DISK FOR CONVERSION ---
# Filesystem      Size  Used Avail Use% Mounted on
# /dev/loop1       20G   14G  6.1G  69% /kaggle/working
#
# --- CONVERTING TO GGUF AND QUANTIZING ---
# Processing ./llama.cpp/gguf-py
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from gguf==0.18.0) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from gguf==0.18.0) (6.0.3)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.12/dist-packages (from gguf==0.18.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from gguf==0.18.0) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->gguf==0.18.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->gguf==0.18.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->gguf==0.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->gguf==0.18.0) (2026.1.4)
# Building wheels for collected packages: gguf
#   Building wheel for gguf (pyproject.toml): started
#   Building wheel for gguf (pyproject.toml): finished with status 'done'
#   Created wheel for gguf: filename=gguf-0.18.0-py3-none-any.whl size=117627 sha256=0c3cb2e455a292890f173fd627fa44f348f1bcf2a7785786a9fea2fd7f7a6f38
#   Stored in directory: /root/.cache/pip/wheels/83/09/0a/003084541f7ecf16ff143fa2d93a4fab02d4e7473a40e17e7f
# Successfully built gguf
# Installing collected packages: gguf
# Successfully installed gguf-0.18.0
# Converting HF to GGUF (FP16)...
# INFO:hf-to-gguf:Loading model: gemma_merged_fp16
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:hf-to-gguf:Model architecture: Gemma4ForConditionalGeneration
# INFO:hf-to-gguf:gguf: indexing model part 'model.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,                 torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:token_embd.weight,                 torch.float16 --> F16, shape = {1536, 262144}
# INFO:hf-to-gguf:per_layer_token_embd.weight,       torch.float16 --> F16, shape = {8960, 262144}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.0.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.0.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.0.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.0.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.0.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.0.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.0.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.0.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.0.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.0.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.0.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.0.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.1.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.1.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.1.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.1.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.1.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.1.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.1.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.1.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.1.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.1.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.1.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.1.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.10.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.10.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,            torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.10.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.10.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.10.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.10.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.10.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.10.attn_k_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.10.attn_k.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.10.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.10.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.10.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.10.attn_v.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.11.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,            torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.11.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.11.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.11.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.11.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.11.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.11.attn_k_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.11.attn_k.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.11.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.11.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.11.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.11.attn_v.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.12.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,            torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.12.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.12.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.12.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.12.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.12.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.12.attn_k_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.12.attn_k.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.12.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.12.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.12.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.12.attn_v.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.13.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,            torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.13.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.13.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.13.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.13.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.13.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.13.attn_k_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.13.attn_k.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.13.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.13.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.13.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.13.attn_v.weight,              torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.14.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,            torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.14.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.14.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.14.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.14.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.14.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.14.attn_k_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.14.attn_k.weight,              torch.float16 --> F16, shape = {1536, 512}
# INFO:hf-to-gguf:blk.14.attn_output.weight,         torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.14.attn_q_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.14.attn_q.weight,              torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.14.attn_v.weight,              torch.float16 --> F16, shape = {1536, 512}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.15.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.15.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.15.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.15.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.15.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.15.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.15.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.15.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.15.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.16.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.16.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.16.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.16.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.16.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.16.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.16.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.16.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.16.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.17.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.17.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.17.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.17.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.17.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.17.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.17.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.17.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.17.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.18.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.18.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.18.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.18.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.18.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.18.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.18.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.18.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.18.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.19.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.19.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.19.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.19.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.19.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.19.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.19.attn_output.weight,         torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.19.attn_q_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.19.attn_q.weight,              torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.2.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.2.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.2.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.2.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.2.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.2.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.2.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.2.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.2.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.2.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.2.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.2.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.20.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.20.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.20.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.20.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.20.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.20.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.20.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.20.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.20.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.20.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.21.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.21.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.21.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.21.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.21.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.21.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.21.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.21.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.21.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.22.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.22.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.22.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.22.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.22.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.22.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.22.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.22.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.22.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.23.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.23.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.23.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.23.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.23.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.23.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.23.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.23.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.23.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.24.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.24.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.24.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.24.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.24.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.24.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.24.attn_output.weight,         torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.24.attn_q_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.24.attn_q.weight,              torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.25.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.25.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.25.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.25.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.25.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.25.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.25.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.25.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.25.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.26.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.26.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.26.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.26.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.26.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.26.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.26.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.26.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.26.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.27.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.27.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.27.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.27.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.27.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.27.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.27.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.27.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.27.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.28.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.28.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.28.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.28.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.28.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.28.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.28.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.28.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.28.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.29.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.29.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.29.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.29.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.29.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.29.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.29.attn_output.weight,         torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.29.attn_q_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.29.attn_q.weight,              torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.3.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.3.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.3.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.3.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.3.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.3.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.3.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.3.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.3.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.3.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.3.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.3.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.30.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.30.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.30.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.30.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.30.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.30.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.30.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.30.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.30.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.31.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.31.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.31.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.31.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.31.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.31.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.31.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.31.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.31.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.32.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.32.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.32.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.32.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.32.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.32.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.32.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.32.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.32.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.32.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.32.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.32.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.32.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.32.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.33.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.33.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.33.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.33.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.33.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.33.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.33.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.33.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.33.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.33.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.33.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.33.attn_output.weight,         torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.33.attn_q_norm.weight,         torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.33.attn_q.weight,              torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.34.attn_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.34.layer_output_scale.weight,  torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.34.ffn_down.weight,            torch.float16 --> F16, shape = {12288, 1536}
# INFO:hf-to-gguf:blk.34.ffn_gate.weight,            torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.34.ffn_up.weight,              torch.float16 --> F16, shape = {1536, 12288}
# INFO:hf-to-gguf:blk.34.inp_gate.weight,            torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.34.proj.weight,                torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.34.post_attention_norm.weight, torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.34.post_ffw_norm.weight,       torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.34.post_norm.weight,           torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.34.ffn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.34.attn_output.weight,         torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.34.attn_q_norm.weight,         torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.34.attn_q.weight,              torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.4.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.4.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.4.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.4.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.4.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.4.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.4.attn_k_norm.weight,          torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.4.attn_k.weight,               torch.float16 --> F16, shape = {1536, 512}
# INFO:hf-to-gguf:blk.4.attn_output.weight,          torch.float16 --> F16, shape = {4096, 1536}
# INFO:hf-to-gguf:blk.4.attn_q_norm.weight,          torch.float16 --> F32, shape = {512}
# INFO:hf-to-gguf:blk.4.attn_q.weight,               torch.float16 --> F16, shape = {1536, 4096}
# INFO:hf-to-gguf:blk.4.attn_v.weight,               torch.float16 --> F16, shape = {1536, 512}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.5.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.5.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.5.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.5.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.5.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.5.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.5.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.5.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.5.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.5.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.5.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.5.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.6.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,             torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,               torch.float16 --> F16, shape = {1536, 6144}
# INFO:hf-to-gguf:blk.6.inp_gate.weight,             torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.6.proj.weight,                 torch.float16 --> F16, shape = {256, 1536}
# INFO:hf-to-gguf:blk.6.post_attention_norm.weight,  torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.6.post_ffw_norm.weight,        torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.6.post_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,             torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.6.attn_k_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.6.attn_k.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.6.attn_output.weight,          torch.float16 --> F16, shape = {2048, 1536}
# INFO:hf-to-gguf:blk.6.attn_q_norm.weight,          torch.float16 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.6.attn_q.weight,               torch.float16 --> F16, shape = {1536, 2048}
# INFO:hf-to-gguf:blk.6.attn_v.weight,               torch.float16 --> F16, shape = {1536, 256}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,            torch.float16 --> F32, shape = {1536}
# INFO:hf-to-gguf:blk.7.layer_output_scale.weight,   torch.float16 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,             torch.float16 --> F16, shape = {6144, 1536}
# ...
#                                     {%- if not loop.last %},{% endif -%}
#                                 {%- endfor -%}
#                                 ]
#                             {%- elif item_key == 'type' -%}
#                                 {%- if item_value is string -%}
#                                     type:{{ format_argument(item_value | upper) }}
#                                 {%- else -%}
#                                     type:{{ format_argument(item_value | map('upper') | list) }}
#                                 {%- endif -%}
#                             {%- else -%}
#                                 {{ item_key }}:{{ format_argument(item_value) }}
#                             {%- endif -%}
#                         {%- endif -%}
#                     {%- endfor -%}
#                     }
#                 {%- endif -%}
#             {%- endif -%}
#             {%- if value['nullable'] %}
#                 {%- if add_comma %},{%- else -%} {%- set add_comma = true -%} {% endif -%}
#                 nullable:true
#             {%- endif -%}
#             {%- if value['type'] | upper == 'OBJECT' -%}
#                 {%- if value['properties'] is defined and value['properties'] is mapping -%}
#                     {%- if add_comma %},{%- else -%} {%- set add_comma = true -%} {% endif -%}
#                     properties:{
#                     {{- format_parameters(value['properties'], value['required'] | default([])) -}}
#                     }
#                 {%- elif value is mapping -%}
#                     {%- if add_comma %},{%- else -%} {%- set add_comma = true -%} {% endif -%}
#                     properties:{
#                     {{- format_parameters(value, value['required'] | default([]), filter_keys=true) -}}
#                     }
#                 {%- endif -%}
#                 {%- if value['required'] -%}
#                     {%- if add_comma %},{%- else -%} {%- set add_comma = true -%} {% endif -%}
#                     required:[
#                     {%- for item in value['required'] | default([]) -%}
#                         <|"|>{{- item -}}<|"|>
#                         {%- if not loop.last %},{% endif -%}
#                     {%- endfor -%}
#                     ]
#                 {%- endif -%}
#             {%- endif -%}
#             {%- if add_comma %},{%- else -%} {%- set add_comma = true -%} {% endif -%}
#             type:<|"|>{{ value['type'] | upper }}<|"|>}
#         {%- endif -%}
#     {%- endfor -%}
# {%- endmacro -%}
# {%- macro format_function_declaration(tool_data) -%}
#     declaration:{{- tool_data['function']['name'] -}}{description:<|"|>{{- tool_data['function']['description'] -}}<|"|>
#     {%- set params = tool_data['function']['parameters'] -%}
#     {%- if params -%}
#         ,parameters:{
#         {%- if params['properties'] -%}
#             properties:{ {{- format_parameters(params['properties'], params['required']) -}} },
#         {%- endif -%}
#         {%- if params['required'] -%}
#             required:[
#             {%- for item in params['required'] -%}
#                 <|"|>{{- item -}}<|"|>
#                 {{- ',' if not loop.last -}}
#             {%- endfor -%}
#             ],
#         {%- endif -%}
#         {%- if params['type'] -%}
#             type:<|"|>{{- params['type'] | upper -}}<|"|>}
#         {%- endif -%}
#     {%- endif -%}
#     {%- if 'response' in tool_data['function'] -%}
#         {%- set response_declaration = tool_data['function']['response'] -%}
#         ,response:{
#         {%- if response_declaration['description'] -%}
#             description:<|"|>{{- response_declaration['description'] -}}<|"|>,
#         {%- endif -%}
#         {%- if response_declaration['type'] | upper == 'OBJECT' -%}
#             type:<|"|>{{- response_declaration['type'] | upper -}}<|"|>}
#         {%- endif -%}
#     {%- endif -%}
#     }
# {%- endmacro -%}
# {%- macro format_argument(argument, escape_keys=True) -%}
#     {%- if argument is string -%}
#         {{- '<|"|>' + argument + '<|"|>' -}}
#     {%- elif argument is boolean -%}
#         {{- 'true' if argument else 'false' -}}
#     {%- elif argument is mapping -%}
#         {{- '{' -}}
#         {%- set ns = namespace(found_first=false) -%}
#         {%- for key, value in argument | dictsort -%}
#             {%- if ns.found_first %},{% endif -%}
#             {%- set ns.found_first = true -%}
#             {%- if escape_keys -%}
#                 {{- '<|"|>' + key + '<|"|>' -}}
#             {%- else -%}
#                 {{- key -}}
#             {%- endif -%}
#             :{{- format_argument(value, escape_keys=escape_keys) -}}
#         {%- endfor -%}
#         {{- '}' -}}
#     {%- elif argument is sequence -%}
#         {{- '[' -}}
#         {%- for item in argument -%}
#             {{- format_argument(item, escape_keys=escape_keys) -}}
#             {%- if not loop.last %},{% endif -%}
#         {%- endfor -%}
#         {{- ']' -}}
#     {%- else -%}
#         {{- argument -}}
#     {%- endif -%}
# {%- endmacro -%}
# {%- macro strip_thinking(text) -%}
#     {%- set ns = namespace(result='') -%}
#     {%- for part in text.split('<channel|>') -%}
#         {%- if '<|channel>' in part -%}
#             {%- set ns.result = ns.result + part.split('<|channel>')[0] -%}
#         {%- else -%}
#             {%- set ns.result = ns.result + part -%}
#         {%- endif -%}
#     {%- endfor -%}
#     {{- ns.result | trim -}}
# {%- endmacro -%}
#
# {%- macro format_tool_response_block(tool_name, response) -%}
#     {{- '<|tool_response>' -}}
#     {%- if response is mapping -%}
#         {{- 'response:' + tool_name + '{' -}}
#         {%- for key, value in response | dictsort -%}
#             {{- key -}}:{{- format_argument(value, escape_keys=False) -}}
#             {%- if not loop.last %},{% endif -%}
#         {%- endfor -%}
#         {{- '}' -}}
#     {%- else -%}
#         {{- 'response:' + tool_name + '{value:' + format_argument(response, escape_keys=False) + '}' -}}
#     {%- endif -%}
#     {{- '<tool_response|>' -}}
# {%- endmacro -%}
#
# {%- set ns = namespace(prev_message_type=None) -%}
# {%- set loop_messages = messages -%}
# {{- bos_token -}}
# {#- Handle System/Tool Definitions Block -#}
# {%- if (enable_thinking is defined and enable_thinking) or tools or messages[0]['role'] in ['system', 'developer'] -%}
#     {{- '<|turn>system\n' -}}
#     {#- Inject Thinking token at the very top of the FIRST system turn -#}
#     {%- if enable_thinking is defined and enable_thinking -%}
#         {{- '<|think|>\n' -}}
#         {%- set ns.prev_message_type = 'think' -%}
#     {%- endif -%}
#     {%- if messages[0]['role'] in ['system', 'developer'] -%}
#         {%- if messages[0]['content'] is string -%}
#             {{- messages[0]['content'] | trim -}}
#         {%- elif messages[0]['content'] is sequence -%}
#             {%- for item in messages[0]['content'] -%}
#                 {{- item['text'] | trim + ' '-}}
#             {%- endfor -%}
#         {%- endif -%}
#         {%- set loop_messages = messages[1:] -%}
#     {%- endif -%}
#     {%- if tools -%}
#         {%- for tool in tools %}
#             {{- '<|tool>' -}}
#             {{- format_function_declaration(tool) | trim -}}
#             {{- '<tool|>' -}}
#         {%- endfor %}
#         {%- set ns.prev_message_type = 'tool' -%}
#     {%- endif -%}
#     {{- '<turn|>\n' -}}
# {%- endif %}
#
# {#- Pre-scan: find last user message index for reasoning guard -#}
# {%- set ns_turn = namespace(last_user_idx=-1) -%}
# {%- for i in range(loop_messages | length) -%}
#     {%- if loop_messages[i]['role'] == 'user' -%}
#         {%- set ns_turn.last_user_idx = i -%}
#     {%- endif -%}
# {%- endfor -%}
#
# {#- Loop through messages -#}
# {%- for message in loop_messages -%}
#     {%- if message['role'] != 'tool' -%}
#     {%- set ns.prev_message_type = None -%}
#     {%- set role = 'model' if message['role'] == 'assistant' else message['role'] -%}
#     {#- Detect continuation: suppress duplicate <|turn>model when previous non-tool message was also assistant -#}
#     {%- set prev_nt = namespace(role=None, found=false) -%}
#     {%- if loop.index0 > 0 -%}
#         {%- for j in range(loop.index0 - 1, -1, -1) -%}
#             {%- if not prev_nt.found -%}
#                 {%- if loop_messages[j]['role'] != 'tool' -%}
#                     {%- set prev_nt.role = loop_messages[j]['role'] -%}
#                     {%- set prev_nt.found = true -%}
#                 {%- endif -%}
#             {%- endif -%}
#         {%- endfor -%}
#     {%- endif -%}
#     {%- set continue_same_model_turn = (role == 'model' and prev_nt.role == 'assistant') -%}
#     {%- if not continue_same_model_turn -%}
#         {{- '<|turn>' + role + '\n' }}
#     {%- endif -%}
#
#     {#- Render reasoning/reasoning_content as thinking channel -#}
#     {%- set thinking_text = message.get('reasoning') or message.get('reasoning_content') -%}
#     {%- if thinking_text and loop.index0 > ns_turn.last_user_idx and message.get('tool_calls') -%}
#         {{- '<|channel>thought\n' + thinking_text + '\n<channel|>' -}}
#     {%- endif -%}
#
#             {%- if message['tool_calls'] -%}
#                 {%- for tool_call in message['tool_calls'] -%}
#                     {%- set function = tool_call['function'] -%}
#                     {{- '<|tool_call>call:' + function['name'] + '{' -}}
#                     {%- if function['arguments'] is mapping -%}
#                         {%- set ns_args = namespace(found_first=false) -%}
#                         {%- for key, value in function['arguments'] | dictsort -%}
#                             {%- if ns_args.found_first %},{% endif -%}
#                             {%- set ns_args.found_first = true -%}
#                             {{- key -}}:{{- format_argument(value, escape_keys=False) -}}
#                         {%- endfor -%}
#                     {%- elif function['arguments'] is string -%}
#                         {{- function['arguments'] -}}
#                     {%- endif -%}
#                     {{- '}<tool_call|>' -}}
#                 {%- endfor -%}
#                 {%- set ns.prev_message_type = 'tool_call' -%}
#             {%- endif -%}
#
#             {%- set ns_tr_out = namespace(flag=false) -%}
#             {%- if message.get('tool_responses') -%}
#                 {#- Legacy: tool_responses embedded on the assistant message (Google/Gemma native) -#}
#                 {%- for tool_response in message['tool_responses'] -%}
#                     {{- format_tool_response_block(tool_response['name'] | default('unknown'), tool_response['response']) -}}
#                     {%- set ns_tr_out.flag = true -%}
#                     {%- set ns.prev_message_type = 'tool_response' -%}
#                 {%- endfor -%}
#             {%- elif message.get('tool_calls') -%}
#                 {#- OpenAI Chat Completions: forward-scan consecutive role:tool messages -#}
#                 {%- set ns_tool_scan = namespace(stopped=false) -%}
#                 {%- for k in range(loop.index0 + 1, loop_messages | length) -%}
#                     {%- if ns_tool_scan.stopped -%}
#                     {%- elif loop_messages[k]['role'] != 'tool' -%}
#                         {%- set ns_tool_scan.stopped = true -%}
#                     {%- else -%}
#                         {%- set follow = loop_messages[k] -%}
#                         {#- Resolve tool_call_id to function name -#}
#                         {%- set ns_tname = namespace(name=follow.get('name') | default('unknown')) -%}
#                         {%- for tc in message['tool_calls'] -%}
#                             {%- if tc.get('id') == follow.get('tool_call_id') -%}
#                                 {%- set ns_tname.name = tc['function']['name'] -%}
#                             {%- endif -%}
#                         {%- endfor -%}
#                         {#- Handle content as string or content-parts array -#}
#                         {%- set tool_body = follow.get('content') -%}
#                         {%- if tool_body is string -%}
#                             {{- format_tool_response_block(ns_tname.name, tool_body) -}}
#                         {%- elif tool_body is sequence and tool_body is not string -%}
#                             {%- set ns_txt = namespace(s='') -%}
#                             {%- for part in tool_body -%}
#                                 {%- if part.get('type') == 'text' -%}
#                                     {%- set ns_txt.s = ns_txt.s + (part.get('text') | default('')) -%}
#                                 {%- endif -%}
#                             {%- endfor -%}
#                             {{- format_tool_response_block(ns_tname.name, ns_txt.s) -}}
#                         {%- else -%}
#                             {{- format_tool_response_block(ns_tname.name, tool_body) -}}
#                         {%- endif -%}
#                         {%- set ns_tr_out.flag = true -%}
#                         {%- set ns.prev_message_type = 'tool_response' -%}
#                     {%- endif -%}
#                 {%- endfor -%}
#             {%- endif -%}
#
#             {%- set captured_content -%}
#             {%- if message['content'] is string -%}
#                 {%- if role == 'model' -%}
#                     {{- strip_thinking(message['content']) -}}
#                 {%- else -%}
#                     {{- message['content'] | trim -}}
#                 {%- endif -%}
#             {%- elif message['content'] is sequence -%}
#                 {%- for item in message['content'] -%}
#                     {%- if item['type'] == 'text' -%}
#                         {%- if role == 'model' -%}
#                             {{- strip_thinking(item['text']) -}}
#                         {%- else -%}
#                             {{- item['text'] | trim -}}
#                         {%- endif -%}
#                     {%- elif item['type'] == 'image' -%}
#                         {{- '<|image|>' -}}
#                         {%- set ns.prev_message_type = 'image' -%}
#                     {%- elif item['type'] == 'audio' -%}
#                         {{- '<|audio|>' -}}
#                         {%- set ns.prev_message_type = 'audio' -%}
#                     {%- elif item['type'] == 'video' -%}
#                         {{- '<|video|>' -}}
#                         {%- set ns.prev_message_type = 'video' -%}
#                     {%- endif -%}
#                 {%- endfor -%}
#             {%- endif -%}
#             {%- endset -%}
#
#             {{- captured_content -}}
#             {%- set has_content = captured_content | trim | length > 0 -%}
#
#         {%- if ns.prev_message_type == 'tool_call' and not ns_tr_out.flag -%}
#             {{- '<|tool_response>' -}}
#         {%- elif not (ns_tr_out.flag and not has_content) -%}
#             {{- '<turn|>\n' -}}
#         {%- endif -%}
#     {%- endif -%}
# {%- endfor -%}
#
# {%- if add_generation_prompt -%}
#     {%- if ns.prev_message_type != 'tool_response' and ns.prev_message_type != 'tool_call' -%}
#         {{- '<|turn>model\n' -}}
#     {%- endif -%}
# {%- endif -%}
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/kaggle/working/ft-gemma-e2b-fp16.gguf: n_tensors = 541, total_size = 9.3G
# Writing:  70%|███████   | 6.48G/9.26G [00:28<00:16, 166Mbyte/s]Traceback (most recent call last):
#   File "/kaggle/working/llama.cpp/convert_hf_to_gguf.py", line 13593, in <module>
#     main()
#   File "/kaggle/working/llama.cpp/convert_hf_to_gguf.py", line 13587, in main
#     model_instance.write()
#   File "/kaggle/working/llama.cpp/convert_hf_to_gguf.py", line 937, in write
#     self.gguf_writer.write_tensors_to_file(progress=True)
#   File "/kaggle/working/llama.cpp/gguf-py/gguf/gguf_writer.py", line 469, in write_tensors_to_file
#     ti.tensor.tofile(fout)
#   File "/kaggle/working/llama.cpp/gguf-py/gguf/lazy.py", line 226, in tofile
#     return eager.tofile(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: Not enough free space to write 37748736 bytes
# Writing:  70%|███████   | 6.48G/9.26G [00:29<00:12, 224Mbyte/s]
# Quantizing to Q4_K_M...
# sh: 1: ./llama.cpp/build/bin/llama-quantize: Permission denied
# --- FINAL FILE ---
#
# --- UPLOADING TO HUGGING FACE ---
#
# ❌ Upload failed: Provided path: '/kaggle/working/ft-gemma-e2b-Q4_K_M.gguf' is not a file on the local file system
# ls: cannot access '/kaggle/working/ft-gemma-e2b-Q4_K_M.gguf': No such file or directory
